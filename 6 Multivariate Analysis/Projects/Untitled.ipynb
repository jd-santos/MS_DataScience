# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
install.packages("MASS")
# Out:
# The downloaded binary packages are in
# 	/var/folders/1n/nvr79nb55tz9j4lsbrw6hsf80000gn/T//RtmpcrP17F/downloaded_packages

# %%
library(MASS)
# Out:
# Warning message:
# “package ‘MASS’ was built under R version 4.0.2”

# %%
Cov <- matrix(c(1, 0.5, 0.5, 1), nrow = 2)

mu <- c(0, 0)

simData <- mvrnorm(n= 100, mu, Cov)
simData
# Out:
#       [,1]         [,2]
#  [1,]  0.717659949 -0.37324767
#  [2,] -0.734772950  1.00278463
#  [3,] -0.281747215 -1.07342013
#  [4,] -1.412204973 -0.73400380
#  [5,] -0.808527648 -1.72310272
#  [6,] -0.225018949 -0.22351729
#  [7,]  0.044867303  0.68727539
#  [8,] -0.294151994  1.34596668
#  [9,]  0.131216970 -1.07560569
# [10,]  1.312896195  1.22017472
# [11,] -0.500209854 -0.25616170
# [12,]  0.933135701  0.72152019
# [13,] -0.510324370 -0.03956327
# [14,]  0.410651345  0.08765694
# [15,]  0.527174541  0.75137977
# [16,]  0.043970643 -1.24215017
# [17,]  0.804343424 -0.61095556
# [18,] -1.162987549 -1.52664457
# [19,]  0.490904831  1.22802037
# [20,] -0.592934918 -0.44255425
# [21,]  1.651473072  2.17163277
# [22,] -2.071379227 -2.10123036
# [23,] -0.383771597  0.07462946
# [24,]  0.105090709  0.02651632
# [25,] -1.797791257  0.80250848
# [26,] -0.133791496  0.12632119
# [27,]  2.412525051  2.23907173
# [28,] -0.260260932 -1.16021079
# [29,]  1.333753748  1.96364775
# ...

# %%
A = matrix(c(4,1,1,1), ncol=2)
A
# Out:
#      [,1] [,2]
# [1,] 4    1
# [2,] 1    1

# %%
cor(A)
# Out:
# Warning message in cor(A):
# “the standard deviation is zero”
#      [,1] [,2]
# [1,]  1   NA
# [2,] NA    1
